# %% [markdown]
# <a href="https://colab.research.google.com/github/dakshesh-1293/AI-ML-Training/blob/main/Classwork/Scikit-Learn/Encoding/OneHotEncoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# from sklearn.preprocessing import OneHotEncoder
#
# encoder = OneHotEncoder(
#     *,
#     categories='auto',
#     drop=None,
#     sparse_output=True,
#     dtype=float,
#     handle_unknown='error',
#     min_frequency=None,
#     max_categories=None,
#     feature_name_combiner='concat'
# )

# %% [markdown]
# ## pd.get_dummies() vs OneHotEncoder

# %% [markdown]
# | Feature                         | `pd.get_dummies()` | `OneHotEncoder`                       |
# | ------------------------------- | ------------------ | ------------------------------------- |
# | Part of scikit-learn pipeline   | ❌                  | ✅                                     |
# | Fit on training, transform test | ❌                  | ✅                                     |
# | Handles unknown categories      | ❌                  | ✅ (`handle_unknown`)                  |
# | Groups rare categories          | ❌                  | ✅ (`min_frequency`, `max_categories`) |
# | Sparse output support           | Limited            | ✅                                     |
# | Easy for EDA                    | ✅                  | ❌                                     |
# | Recommended for ML pipelines    | ❌                  | ✅                                     |

# %% [markdown]
# ## 1. categories
# Purpose
#
# Specifies which categories should be encoded.
#
# Default
#
# categories='auto'
#
# This means the encoder automatically detects unique values.

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.DataFrame({
    'Color':['Red','Blue','Green']
})

encoder = OneHotEncoder()
df = encoder.fit(df)
df
# Out:
# OneHotEncoder()

# %%
df
# Out:
# OneHotEncoder()

# %% [markdown]
# ##### Manual Categories
#
# Now it will always expect these categories.
#
# Useful when
#
# Training and testing datasets differ.
# You want fixed columns.
#
# Example :-
#
# **Training**
#
# Blue
# Red
#
# **Testing**
#
# Green
#
# >Without predefined categories, Green could cause issues depending on handle_unknown.

# %%
encoder = OneHotEncoder(
    categories=[['Blue','Green','Red']]
)

# %% [markdown]
# ## 2. drop
# Purpose
#
# Drops one category from each feature.
#
# Default : drop=None

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(
    sparse_output=False,
    dtype=int
)

encoder.fit_transform([['Male'], ['Female'], ['Male'], ['Female']])
# Out:
# array([[0, 1],
#        [1, 0],
#        [0, 1],
#        [1, 0]])

# %%
encoder = OneHotEncoder(
    drop='first',
    sparse_output=False,
    dtype=int
)

# %%
# Out:
# OneHotEncoder(drop='first', dtype=<class 'int'>, sparse_output=False)

# %%
encoder
# Out:
# OneHotEncoder(drop='first', dtype=<class 'int'>, sparse_output=False)

# %%
df
# Out:
# OneHotEncoder()
