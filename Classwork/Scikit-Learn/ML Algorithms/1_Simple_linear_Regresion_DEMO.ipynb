# %% [markdown]
# <a href="https://colab.research.google.com/github/dakshesh-1293/AI-ML-Training/blob/main/Classwork/Scikit-Learn/ML%20Algorithms/1_Simple_linear_Regresion_DEMO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Step 1: Import Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Step 2: Create Dataset**

# %%
data = {
    "Area": [1000, 1500, 2000, 2200, 2400, 2500],
    "Price": [30, 45, 60, 64, 66,69]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Area  Price
# 0  1000     30
# 1  1500     45
# 2  2000     60
# 3  2200     64
# 4  2400     66
# 5  2500     69

# %% [markdown]
# **Step 3: Separate Independent and Dependent Variables**

# %%
X = df[["Area"]]     # Independent Variable
y = df["Price"]      # Dependent Variable

# X must be in 2D

# %% [markdown]
# **Step 4: Create Model**

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %% [markdown]
# **Step 5: Train Model**

# %%
model.fit(X, y)

# Slope (m)
# Intercept (c)
# Out:
# LinearRegression()

# %% [markdown]
# **Step 6: Print Equation**

# %%
print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)


# Price = 0.02 × Area + 5.44
# Out:
# Slope: 0.025976095617529883
# Intercept: 5.446215139442224

# %% [markdown]
# **Step 7: Predict New Price**

# %%
prediction = model.predict([[1800]])

print("Predicted Price:", prediction[0], "Lakhs")
# Out:
# Predicted Price: 52.20318725099601 Lakhs
# C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **Step 8: Predict Multiple Houses**

# %%
new_area = [[1200], [1700], [2500]]

predictions = model.predict(new_area)

print(predictions)
# Out:
# [36.61752988 49.60557769 70.38645418]
# C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **Step 9: Plot Regression Line**

# %%
plt.figure(figsize=(7,5))

plt.scatter(X, y, color="blue", label="Actual Data")

plt.plot(X, model.predict(X),
         color="red",
         linewidth=2,
         label="Regression Line")

plt.xlabel("Area (sq ft)")
plt.ylabel("Price (Lakhs)")
plt.title("Simple Linear Regression")
plt.legend()

plt.show()

# %% [markdown]
# **Step 10: Evaluate Model**
#
# - MAE: Average prediction error in the same units as the target.
# - MSE: Penalizes larger errors more heavily.
# - RMSE: Typical prediction error.
# - R²: How much of the target's variation is explained by the model (closer to 1 is better).
#
#
# #### R² Score (Coefficient of Determination)
# - 1     → Perfect prediction
# - 0.9   → Very Good
# - 0.8   → Good
# - 0.5   → Average
# - 0     → Model is no better than predicting the mean
# - <0    → Very Bad Model

# %%
from sklearn.metrics import r2_score

pred = model.predict(X)

print("R² Score:", r2_score(y, pred))
# Out:
# R² Score: 0.985821556614056

# %%
print(data)
print(new_area)
print(predictions)
# Out:
# {'Area': [1000, 1500, 2000, 2200, 2400, 2500], 'Price': [30, 45, 60, 64, 66, 69]}
# [[1200], [1700], [2500]]
# [36.61752988 49.60557769 70.38645418]
